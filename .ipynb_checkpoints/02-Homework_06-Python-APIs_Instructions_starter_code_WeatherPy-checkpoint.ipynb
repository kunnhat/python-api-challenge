# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st

# Import API key
from api import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # Replace spaces with %20 to create url correctly 
    city = city.replace(" ", "%20")
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:

        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=leshukonskoye
# Processing Record 2 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=vaini
# Processing Record 3 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=camacha
# Processing Record 4 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=pisco
# Processing Record 5 | Kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kudahuvadhoo
# Processing Record 6 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=cherskiy
# Processing Record 7 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=hambantota
# Processing Record 8 | Maridi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=maridi
# Processing Record 9 | Tateyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=tateyama
# Processing Record 10 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ushuaia
# Processing Record 11 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=castro
# Processing Record 12 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=marawi
# Processing Record 13 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ilulissat
# Processing Record 14 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=qaanaaq
# Processing Record 15 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=hermanus
# Processing Record 16 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=busselton
# City not found. Skipping...
# Processing Record 17 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=upernavik
# Processing Record 18 | Neuquén
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=neuquen
# Processing Record 19 | Ternate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ternate
# Processing Record 20 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=tuktoyaktuk
# Processing Record 21 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=new%20norfolk
# Processing Record 22 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=lompoc
# Processing Record 23 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=albany
# Processing Record 24 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=cape%20town
# Processing Record 25 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=dingle
# Processing Record 26 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=fortuna
# Processing Record 27 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=grand%20gaube
# Processing Record 28 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=saint%20anthony
# Processing Record 29 | Xingcheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=xingcheng
# Processing Record 30 | Japura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=japura
# Processing Record 31 | Mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mogadishu
# Processing Record 32 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=hobart
# Processing Record 33 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=tautira
# Processing Record 34 | Jiangyou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=jiangyou
# Processing Record 35 | Samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=samarai
# Processing Record 36 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=cidreira
# Processing Record 37 | Lajas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=lajas
# Processing Record 38 | Mizdah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mizdah
# City not found. Skipping...
# Processing Record 39 | Asău
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=asau
# Processing Record 40 | Labuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=labuan
# Processing Record 41 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=cabo%20san%20lucas
# Processing Record 42 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=yellowknife
# City not found. Skipping...
# Processing Record 43 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=punta%20arenas
# Processing Record 44 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kalmunai
# Processing Record 45 | Bella Vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bella%20vista
# Processing Record 46 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=avarua
# Processing Record 47 | Filingué
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=filingue
# Processing Record 48 | Rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=rocha
# Processing Record 49 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=chokurdakh
# Processing Record 50 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=barrow
# Processing Record 51 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=nikolskoye
# Processing Record 52 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bathsheba
# Processing Record 53 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ambilobe
# City not found. Skipping...
# Processing Record 54 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bethel
# Processing Record 55 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=rikitea
# Processing Record 56 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=butaritari
# Processing Record 57 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mataura
# Processing Record 58 | Socorro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=socorro
# Processing Record 59 | Mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mareeba
# Processing Record 60 | Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=sur
# Processing Record 61 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=longyearbyen
# Processing Record 62 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=khatanga
# Processing Record 63 | Olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=olafsvik
# Processing Record 64 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kruisfontein
# Processing Record 65 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=atuona
# Processing Record 66 | Luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=luanda
# Processing Record 67 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=east%20london
# Processing Record 68 | Rudnichnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=rudnichnyy
# City not found. Skipping...
# Processing Record 69 | Maceió
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=maceio
# Processing Record 70 | Yairipok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=yairipok
# City not found. Skipping...
# Processing Record 71 | Machico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=machico
# Processing Record 72 | Kortkeros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kortkeros
# Processing Record 73 | Letpadan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=letpadan
# City not found. Skipping...
# Processing Record 74 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=alofi
# Processing Record 75 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=thompson
# Processing Record 76 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=katsuura
# Processing Record 77 | Rørvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=rorvik
# Processing Record 78 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=arraial%20do%20cabo
# City not found. Skipping...
# Processing Record 79 | Delta del Tigre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=delta%20del%20tigre
# Processing Record 80 | Shingū
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=shingu
# Processing Record 81 | Takoradze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=takoradi
# Processing Record 82 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=clyde%20river
# Processing Record 83 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=jamestown
# Processing Record 84 | Khovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=hovd
# City not found. Skipping...
# Processing Record 85 | Luang Prabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=luang%20prabang
# Processing Record 86 | Bara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bara
# Processing Record 87 | Awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=awjilah
# Processing Record 88 | Buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=buchanan
# Processing Record 89 | Mangan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mangan
# Processing Record 90 | Pedasí
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=pedasi
# Processing Record 91 | Zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=zhangye
# City not found. Skipping...
# Processing Record 92 | Fort Walton Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=fort%20walton%20beach
# Processing Record 93 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=port%20alfred
# Processing Record 94 | Lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=lata
# Processing Record 95 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bluff
# Processing Record 96 | Wiarton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=wiarton
# Processing Record 97 | Harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=harper
# Processing Record 98 | Karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=karratha
# Processing Record 99 | Yerbogachën
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=yerbogachen
# City not found. Skipping...
# Processing Record 100 | Dawlatabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=dawlatabad
# Processing Record 101 | Yarim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=yarim
# City not found. Skipping...
# Processing Record 102 | São João da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=sao%20joao%20da%20barra
# Processing Record 103 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=puerto%20ayora
# Processing Record 104 | Sorab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=sorab
# Processing Record 105 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=hithadhoo
# Processing Record 106 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bandarbeyla
# City not found. Skipping...
# Processing Record 107 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=port%20elizabeth
# Processing Record 108 | Guiglo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=guiglo
# Processing Record 109 | Gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=gamba
# Processing Record 110 | Trincomalee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=trincomalee
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 111 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mar%20del%20plata
# Processing Record 112 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=isangel
# Processing Record 113 | Mozelos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mozelos
# Processing Record 114 | Oistins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=oistins
# Processing Record 115 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kapaa
# Processing Record 116 | Lüderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=luderitz
# Processing Record 117 | Chunian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=chunian
# Processing Record 118 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=tasiilaq
# Processing Record 119 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=saint-philippe
# Processing Record 120 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=avera
# Processing Record 121 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=carnarvon
# Processing Record 122 | Yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=yaan
# Processing Record 123 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=poum
# Processing Record 124 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kamenka
# Processing Record 125 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=torbay
# City not found. Skipping...
# Processing Record 126 | Payakumbuh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=payakumbuh
# Processing Record 127 | Salekhard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=salekhard
# Processing Record 128 | Kattivākkam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kattivakkam
# Processing Record 129 | Severo-Kuril'sk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=severo-kurilsk
# Processing Record 130 | Banjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=banjar
# Processing Record 131 | Hong Kong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=victoria
# City not found. Skipping...
# Processing Record 132 | Manaure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=manaure
# Processing Record 133 | Magdalena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=magdalena
# Processing Record 134 | Shubarshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=shubarshi
# Processing Record 135 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ketchikan
# Processing Record 136 | Bairiki Village
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bairiki
# Processing Record 137 | Mamu Kanjan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mamu%20kanjan
# Processing Record 138 | Tsiroanomandidy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=tsiroanomandidy
# Processing Record 139 | Chui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=chuy
# Processing Record 140 | Manono
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=manono
# Processing Record 141 | Korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=korla
# Processing Record 142 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bredasdorp
# Processing Record 143 | Ivangorod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ivangorod
# Processing Record 144 | Pachino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=pachino
# Processing Record 145 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mehamn
# Processing Record 146 | Kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kirakira
# Processing Record 147 | Coahuayana Viejo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=coahuayana
# Processing Record 148 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=airai
# City not found. Skipping...
# Processing Record 149 | Cisneros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=cisneros
# Processing Record 150 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=vao
# Processing Record 151 | Iguaí
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=iguai
# Processing Record 152 | Berlevåg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=berlevag
# Processing Record 153 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=fairbanks
# Processing Record 154 | Mossamedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=namibe
# Processing Record 155 | Las Vegas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=las%20vegas
# Processing Record 156 | Bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bengkulu
# Processing Record 157 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ribeira%20grande
# Processing Record 158 | Gonder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=gondar
# Processing Record 159 | Jinxiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=jinxiang
# Processing Record 160 | Tazovsky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=tazovskiy
# Processing Record 161 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=half%20moon%20bay
# Processing Record 162 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kununurra
# Processing Record 163 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=tessalit
# Processing Record 164 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=college
# Processing Record 165 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=dikson
# Processing Record 166 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=adrar
# Processing Record 167 | Béboto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=beboto
# Processing Record 168 | São Sebastião
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=sao%20sebastiao
# Processing Record 169 | Kjøllefjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kjollefjord
# Processing Record 170 | La Palma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=la%20palma
# Processing Record 171 | Sioux City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=sioux%20city
# Processing Record 172 | Mahébourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mahebourg
# Processing Record 173 | Esna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=esna
# Processing Record 174 | Nieuw Amsterdam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=nieuw%20amsterdam
# City not found. Skipping...
# Processing Record 175 | Chiredzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=chiredzi
# Processing Record 176 | Biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=biak
# Processing Record 177 | Macaé
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=macae
# Processing Record 178 | Uruguaiana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=uruguaiana
# Processing Record 179 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=hilo
# Processing Record 180 | Broken Hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=broken%20hill
# City not found. Skipping...
# Processing Record 181 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=san%20patricio
# Processing Record 182 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=faanui
# Processing Record 183 | Porbandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=porbandar
# Processing Record 184 | Klaksvík
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=klaksvik
# City not found. Skipping...
# Processing Record 185 | Beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=beloha
# Processing Record 186 | Perdões
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=perdoes
# Processing Record 187 | Balasheyka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=balasheyka
# Processing Record 188 | Owando
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=owando
# City not found. Skipping...
# Processing Record 189 | Dingzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=dingzhou
# Processing Record 190 | Sigli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=sigli
# Processing Record 191 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=paamiut
# Processing Record 192 | Kholtoson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kholtoson
# Processing Record 193 | Eenhana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=eenhana
# Processing Record 194 | Srivaikuntam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=srivaikuntam
# Processing Record 195 | Mahajanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mahajanga
# Processing Record 196 | Kroya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kroya
# Processing Record 197 | São Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=sao%20filipe
# Processing Record 198 | Tortolì
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=tortoli
# Processing Record 199 | Bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bonthe
# Processing Record 200 | Acapulco de Juárez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=acapulco
# Processing Record 201 | Ardabil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ardabil
# Processing Record 202 | Pārsābād
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=parsabad
# Processing Record 203 | Tungor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=tungor
# Processing Record 204 | Mizhhirya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=volovo
# Processing Record 205 | George Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=georgetown
# Processing Record 206 | Salamiyah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=salamiyah
# Processing Record 207 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=souillac
# Processing Record 208 | Folldal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=folldal
# Processing Record 209 | Fremont
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=fremont
# Processing Record 210 | Semporna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=semporna
# Processing Record 211 | Riacho de Santana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=riacho%20de%20santana
# Processing Record 212 | Fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=fare
# Processing Record 213 | Talas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=talas
# Processing Record 214 | Genhe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=genhe
# Processing Record 215 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=husavik
# Processing Record 216 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=nome
# Processing Record 217 | East Wenatchee Bench
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=east%20wenatchee%20bench
# Processing Record 218 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=grindavik
# Processing Record 219 | Viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=viedma
# Processing Record 220 | Inírida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=inirida
# Processing Record 221 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kavaratti
# Processing Record 222 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=geraldton
# Processing Record 223 | Gayny
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=gayny
# Processing Record 224 | Slave Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=slave%20lake
# Processing Record 225 | Kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kenai
# Processing Record 226 | Iraray
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=iraray
# Processing Record 227 | Nishifukuma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=fukuma
# Processing Record 228 | Goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=goderich
# Processing Record 229 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=saint%20george
# Processing Record 230 | Urrao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=urrao
# Processing Record 231 | Dillon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=dillon
# Processing Record 232 | Leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=leh
# Processing Record 233 | Ucluelet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ucluelet
# Processing Record 234 | Ola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ola
# Processing Record 235 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ancud
# Processing Record 236 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=saldanha
# Processing Record 237 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bubaque
# Processing Record 238 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=pacific%20grove
# Processing Record 239 | Tiznit Province
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=tiznit
# Processing Record 240 | La Sarre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=la%20sarre
# Processing Record 241 | Sinegor'ye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=sinegorye
# Processing Record 242 | Oconomowoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=oconomowoc
# Processing Record 243 | Ipinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ipinda
# Processing Record 244 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=richards%20bay
# Processing Record 245 | Kralendijk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kralendijk
# Processing Record 246 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=necochea
# Processing Record 247 | Posadas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=posadas
# Processing Record 248 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=yulara
# Processing Record 249 | Izvestkovyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=izvestkovyy
# Processing Record 250 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=nuuk
# City not found. Skipping...
# Processing Record 251 | Al Bardīyah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bardiyah
# Processing Record 252 | Golden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=golden
# Processing Record 253 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=norman%20wells
# Processing Record 254 | Qeshm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=qeshm
# Processing Record 255 | Ürümqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=urumqi
# Processing Record 256 | San Quintín
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=san%20quintin
# Processing Record 257 | Ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ixtapa
# City not found. Skipping...
# Processing Record 258 | Vytegra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=vytegra
# Processing Record 259 | ‘Āhuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ahuimanu
# Processing Record 260 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=hobyo
# Processing Record 261 | Östersund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ostersund
# Processing Record 262 | Diffa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=diffa
# Processing Record 263 | Bridgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bridgetown
# Processing Record 264 | Bluefield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bluefield
# Processing Record 265 | Micheweni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=micheweni
# Processing Record 266 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=maniitsoq
# Processing Record 267 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=vila%20velha
# Processing Record 268 | Mwense
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mwense
# Processing Record 269 | Nakamura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=nakamura
# Processing Record 270 | Ellensburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ellensburg
# Processing Record 271 | Itumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=itumba
# Processing Record 272 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=port%20blair
# Processing Record 273 | Morón
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=moron
# Processing Record 274 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=lagoa
# Processing Record 275 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=nanortalik
# Processing Record 276 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bambous%20virieux
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 277 | Río Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=rio%20gallegos
# Processing Record 278 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=faya
# Processing Record 279 | Palu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=palu
# City not found. Skipping...
# Processing Record 280 | Payo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=payo
# Processing Record 281 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=sitka
# Processing Record 282 | Wadi Maliz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=wadi%20maliz
# Processing Record 283 | Darhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=darhan
# Processing Record 284 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=lebu
# Processing Record 285 | Kuala Terengganu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kuala%20terengganu
# Processing Record 286 | Lavumisa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=lavumisa
# Processing Record 287 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=codrington
# City not found. Skipping...
# Processing Record 288 | Sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=sola
# Processing Record 289 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=hasaki
# Processing Record 290 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=carutapera
# Processing Record 291 | Le Mans
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=le%20mans
# Processing Record 292 | Kurumkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kurumkan
# Processing Record 293 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=te%20anau
# Processing Record 294 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=provideniya
# Processing Record 295 | Sanchursk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=sanchursk
# Processing Record 296 | Saint Paul Harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kodiak
# City not found. Skipping...
# Processing Record 297 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=henties%20bay
# Processing Record 298 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ostrovnoy
# Processing Record 299 | Jining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=jining
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 300 | Kumul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=hami
# Processing Record 301 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=saskylakh
# Processing Record 302 | Great Yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=great%20yarmouth
# Processing Record 303 | Bocas del Toro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bocas%20del%20toro
# Processing Record 304 | Tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=tommot
# Processing Record 305 | Ust-Kuyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ust-kuyga
# Processing Record 306 | Porto Recanati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=porto%20recanati
# Processing Record 307 | Katobu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=katobu
# Processing Record 308 | Belyy Yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=belyy%20yar
# Processing Record 309 | Coyhaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=coihaique
# Processing Record 310 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=cayenne
# Processing Record 311 | Lethem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=lethem
# Processing Record 312 | Abay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=abay
# Processing Record 313 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=esperance
# Processing Record 314 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=tiksi
# Processing Record 315 | Inta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=inta
# Processing Record 316 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=nantucket
# Processing Record 317 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kavieng
# Processing Record 318 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kieta
# Processing Record 319 | Contamana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=contamana
# Processing Record 320 | Fukuchiyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=fukuchiyama
# Processing Record 321 | Verāval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=veraval
# Processing Record 322 | Ust-Tsilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ust-tsilma
# Processing Record 323 | Zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=zhangjiakou
# City not found. Skipping...
# Processing Record 324 | Marsh Harbour
# ...
# Processing Record 444 | Rabo de Peixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=rabo%20de%20peixe
# Processing Record 445 | Kasangulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kasangulu
# Processing Record 446 | Werota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=werota
# Processing Record 447 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=salalah
# Processing Record 448 | Xinan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=xinan
# Processing Record 449 | Mizhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=zhucheng
# Processing Record 450 | Mikuni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mikuni
# Processing Record 451 | Nova Olímpia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=nova%20olimpia
# Processing Record 452 | Esim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=axim
# Processing Record 453 | Bograd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bograd
# Processing Record 454 | Dalvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=dalvik
# City not found. Skipping...
# Processing Record 455 | Verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=verkhnevilyuysk
# Processing Record 456 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mount%20isa
# Processing Record 457 | Bonnyville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bonnyville
# Processing Record 458 | Bushehr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bushehr
# Processing Record 459 | Nouakchott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=nouakchott
# Processing Record 460 | Ambon City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ambon
# Processing Record 461 | Falun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=falun
# Processing Record 462 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=portland
# Processing Record 463 | Facatativá
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=facatativa
# Processing Record 464 | Merano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=merano
# City not found. Skipping...
# Processing Record 465 | Karasjok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=karasjok
# Processing Record 466 | Santa Cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=agadir
# Processing Record 467 | Māngrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mangrol
# Processing Record 468 | Zabaykal'sk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=zabaykalsk
# Processing Record 469 | Boshnyakovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=boshnyakovo
# Processing Record 470 | Iwanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=iwanai
# Processing Record 471 | Mbale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mbale
# Processing Record 472 | Kalat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kalat
# Processing Record 473 | Hay River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=hay%20river
# Processing Record 474 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=vila%20franca%20do%20campo
# Processing Record 475 | Olavarría
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=olavarria
# Processing Record 476 | Shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=shelburne
# City not found. Skipping...
# Processing Record 477 | Dunyapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=dunyapur
# Processing Record 478 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=lavrentiya
# Processing Record 479 | Saint-François
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=saint-francois
# Processing Record 480 | Rosarito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=rosarito
# Processing Record 481 | Vredendal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=vredendal
# Processing Record 482 | Nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=nishihara
# Processing Record 483 | Opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=opuwo
# Processing Record 484 | Turki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=turki
# Processing Record 485 | Kostomuksha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kostomuksha
# Processing Record 486 | Altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=altay
# Processing Record 487 | Madang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=madang
# Processing Record 488 | Dryden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=dryden
# Processing Record 489 | Sortland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=sortland
# Processing Record 490 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=port%20hardy
# Processing Record 491 | Arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=arlit
# Processing Record 492 | Evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=evensk
# City not found. Skipping...
# Processing Record 493 | Miyako
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=miyako
# Processing Record 494 | Livingston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=livingston
# Processing Record 495 | Kariba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kariba
# Processing Record 496 | Bad Lippspringe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bad%20lippspringe
# Processing Record 497 | Raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=raudeberg
# Processing Record 498 | Witbank
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=witbank
# Processing Record 499 | Moñitos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=monitos
# Processing Record 500 | Beian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=beian
# Processing Record 501 | Motala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=motala
# Processing Record 502 | Bodden Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bodden%20town
# Processing Record 503 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=iqaluit
# Processing Record 504 | Gao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=gao
# Processing Record 505 | Meïganga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=meiganga
# Processing Record 506 | Marang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=marang
# Processing Record 507 | General Pico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=general%20pico
# Processing Record 508 | Killam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=killam
# Processing Record 509 | Morro Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=morro%20bay
# Processing Record 510 | Touba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=touba
# Processing Record 511 | Villazón
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=villazon
# Processing Record 512 | Karasuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=karasuk
# Processing Record 513 | Bershet'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=bershet
# Processing Record 514 | De-Kastri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=de-kastri
# Processing Record 515 | Mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mandalgovi
# Processing Record 516 | Kampene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kampene
# Processing Record 517 | At-Bashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=at-bashi
# City not found. Skipping...
# Processing Record 518 | Zharkent
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=zharkent
# City not found. Skipping...
# Processing Record 519 | Buin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=buin
# Processing Record 520 | Poronaysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=poronaysk
# Processing Record 521 | Baikunthpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=baikunthpur
# Processing Record 522 | Capreol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=capreol
# Processing Record 523 | Varhaug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=varhaug
# Processing Record 524 | Champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=champerico
# Processing Record 525 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=saint-augustin
# Processing Record 526 | Taiyuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=taiyuan
# Processing Record 527 | Jinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=jinka
# Processing Record 528 | Pedro Carbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=pedro%20carbo
# Processing Record 529 | Mokhsogollokh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mokhsogollokh
# Processing Record 530 | North Bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=north%20bend
# Processing Record 531 | Shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=shenjiamen
# Processing Record 532 | Chānasma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=chanasma
# Processing Record 533 | Lukaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=lukaya
# Processing Record 534 | Mulegé
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mulege
# Processing Record 535 | Boa Vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=boa%20vista
# Processing Record 536 | Vihti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=vihti
# Processing Record 537 | San-Pédro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=san-pedro
# Processing Record 538 | Benjamín Aceval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=benjamin%20aceval
# Processing Record 539 | Baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=baykit
# Processing Record 540 | Fes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=fez
# Processing Record 541 | Santiago del Estero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=santiago%20del%20estero
# Processing Record 542 | Mundgod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mundgod
# Processing Record 543 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=margate
# Processing Record 544 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=mount%20gambier
# Processing Record 545 | Ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=ulaangom
# Processing Record 546 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=kahului
# Processing Record 547 | Daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=daru
# City not found. Skipping...
# Processing Record 548 | Almeirim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=almeirim
# Processing Record 549 | Lewiston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=lewiston
# Processing Record 550 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=leningradskiy
# Processing Record 551 | Inowrocław
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=081a00f8535c15c49fbe5219e327d5c5&q=inowroclaw

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          551
# Cloudiness    551
# Country       551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Max Temp      551
# Wind Speed    551
# dtype: int64

# %%
# Save data frame to CSV
weather_data.to_csv('weather.csv')

# Display data frame head 
weather_data.head()
# Out:
#             City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0  Leshukonskoye          95      RU  1617701521        76  64.8989   45.7622
# 1          Vaini          40      TO  1617701522        83 -21.2000 -175.2000
# 2        Camacha           0      PT  1617701523        63  33.0833  -16.3333
# 3          Pisco          53      PE  1617701524        83 -13.7000  -76.2167
# 4   Kudahuvadhoo          86      MV  1617701526        69   2.6708   72.8944
#
#    Max Temp  Wind Speed
# 0     42.89       12.62
# 1     75.20        4.61
# 2     66.20        8.05
# 3     68.00        9.22
# 4     83.46       10.87

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern = weather_data.loc[weather_data["Lat"] >= 0.0]
northern.reset_index(inplace=True)

southern = weather_data.loc[weather_data["Lat"] < 0.0]
southern.reset_index(inplace=True)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern["Lat"]
y_values = northern["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Temperatures at Latitude Positions (Northern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.ylim(-5, 100)
plt.xlim(0, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("lat_temp_northern_regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern["Lat"]
y_values = southern["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Temperatures at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35,80),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.ylim(40, 100)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("lat_temp_southern_regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern["Lat"]
y_values = northern["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Humidity at Latitude Positions (Northern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(0, 105)
plt.xlim(0, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("lat_humid_northern_regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern["Lat"]
y_values = southern["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Humidity at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35,80),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(0, 105)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
#plt.tight_layout()
plt.show()
plt.savefig("lat_humid_southern_regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern["Lat"]
y_values = northern["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Cloudiness at Latitude Positions (Northern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.ylim(-5, 105)
plt.xlim(0, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("lat_clouds_northern_regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern["Lat"]
y_values = southern["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Cloudiness at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,60),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.ylim(-5, 105)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
#plt.tight_layout()
plt.show()
plt.savefig("lat_clouds_southern_regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern["Lat"]
y_values = northern["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Wind Speed at Latitude Positions (Northern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.ylim(0, 40)
plt.xlim(0, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("lat_wind_northern_regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern["Lat"]
y_values = southern["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Wind Speed at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.ylim(0, 35)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
#plt.tight_layout()
plt.show()
plt.savefig("lat_wind_southern_regression.png")
